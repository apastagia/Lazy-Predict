# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
# Out:
# F:\ancnd\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   test_size = 0.25,
                                                   random_state = 123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True,
                    custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  8.15it/s]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# RandomForestClassifier             0.99               0.99     0.99      0.99
# QuadraticDiscriminantAnalysis      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.98     0.98      0.99
# SVC                                0.99               0.98     0.98      0.99
# RidgeClassifierCV                  0.99               0.98     0.98      0.99
# RidgeClassifier                    0.99               0.98     0.98      0.99
# ExtraTreesClassifier               0.99               0.98     0.98      0.99
# LabelPropagation                   0.98               0.98     0.98      0.98
# LabelSpreading                     0.98               0.98     0.98      0.98
# SGDClassifier                      0.98               0.98     0.98      0.98
# Perceptron                         0.98               0.98     0.98      0.98
# LGBMClassifier                     0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.98     0.98      0.98
# DecisionTreeClassifier             0.98               0.98     0.98      0.98
# BernoulliNB                        0.98               0.98     0.98      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# AdaBoostClassifier                 0.97               0.97     0.97      0.97
# PassiveAggressiveClassifier        0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BaggingClassifier                  0.97               0.96     0.96      0.97
# NearestCentroid                    0.97               0.95     0.95      0.96
# NuSVC                              0.97               0.95     0.95      0.96
# GaussianNB                         0.97               0.95     0.95      0.96
# ExtraTreeClassifier                0.94               0.94     0.94      0.94
# DummyClassifier                    0.57               0.53     0.53      0.56
#
#                                Time Taken
# Model
# LogisticRegression                   0.06
# RandomForestClassifier               0.29
# QuadraticDiscriminantAnalysis        0.09
# LinearSVC                            0.03
# SVC                                  0.02
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.13
# ExtraTreesClassifier                 0.20
# LabelPropagation                     0.10
# LabelSpreading                       0.04
# SGDClassifier                        0.02
# Perceptron                           0.02
# LGBMClassifier                       0.21
# KNeighborsClassifier                 0.12
# DecisionTreeClassifier               0.02
# BernoulliNB                          0.10
# LinearDiscriminantAnalysis           0.13
# CalibratedClassifierCV               0.11
# AdaBoostClassifier                   0.24
# PassiveAggressiveClassifier          0.04
# XGBClassifier                        1.30
# BaggingClassifier                    0.08
# NearestCentroid                      0.02
# NuSVC                                0.03
# GaussianNB                           0.02
# ExtraTreeClassifier                  0.03
# DummyClassifier                      0.04

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state = 1)

# %%
offset = int(X.shape[0] * 0.9)

# %%
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:04<00:00,  9.60it/s]

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.88       0.91  2.25        0.30
# HistGradientBoostingRegressor                0.87       0.91  2.30        1.00
# RandomForestRegressor                        0.87       0.90  2.36        0.46
# BaggingRegressor                             0.86       0.90  2.38        0.07
# LGBMRegressor                                0.86       0.90  2.40        0.19
# GradientBoostingRegressor                    0.86       0.89  2.42        0.21
# XGBRegressor                                 0.85       0.89  2.48        0.15
# AdaBoostRegressor                            0.81       0.86  2.80        0.15
# PoissonRegressor                             0.79       0.85  2.92        0.02
# KNeighborsRegressor                          0.79       0.84  2.97        0.03
# SVR                                          0.74       0.80  3.31        0.02
# NuSVR                                        0.72       0.79  3.43        0.02
# LinearSVR                                    0.71       0.79  3.44        0.01
# HuberRegressor                               0.71       0.79  3.44        0.05
# DecisionTreeRegressor                        0.68       0.77  3.62        0.02
# GammaRegressor                               0.68       0.76  3.65        0.01
# LarsCV                                       0.67       0.76  3.69        0.04
# BayesianRidge                                0.67       0.76  3.69        0.01
# LassoLarsCV                                  0.67       0.76  3.69        0.04
# LassoCV                                      0.67       0.76  3.69        0.10
# ElasticNetCV                                 0.67       0.76  3.69        0.10
# LassoLarsIC                                  0.67       0.75  3.71        0.02
# SGDRegressor                                 0.67       0.75  3.72        0.02
# Ridge                                        0.66       0.75  3.73        0.01
# RidgeCV                                      0.66       0.75  3.73        0.01
# LinearRegression                             0.66       0.75  3.73        0.01
# TransformedTargetRegressor                   0.66       0.75  3.73        0.01
# Lars                                         0.66       0.75  3.76        0.02
# MLPRegressor                                 0.66       0.75  3.76        0.88
# GaussianProcessRegressor                     0.64       0.73  3.86        0.05
# GeneralizedLinearRegressor                   0.63       0.73  3.90        0.01
# TweedieRegressor                             0.63       0.73  3.90        0.01
# ElasticNet                                   0.62       0.72  3.95        0.03
# OrthogonalMatchingPursuitCV                  0.61       0.71  4.00        0.02
# Lasso                                        0.60       0.70  4.07        0.02
# ExtraTreeRegressor                           0.59       0.70  4.11        0.02
# PassiveAggressiveRegressor                   0.52       0.64  4.48        0.01
# OrthogonalMatchingPursuit                    0.35       0.52  5.20        0.01
# RANSACRegressor                              0.02       0.27  6.38        0.09
# DummyRegressor                              -0.49      -0.11  7.87        0.01
# LassoLars                                   -0.49      -0.11  7.87        0.02
# KernelRidge                                -11.27      -8.08 22.55        0.03

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male 22.00      1      0  7.25        S  Third    man
# 1         1       1  female 38.00      1      0 71.28        C  First  woman
# 2         1       3  female 26.00      0      0  7.92        S  Third  woman
# 3         1       1  female 35.00      1      0 53.10        S  First  woman
# 4         0       3    male 35.00      0      0  8.05        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
X = df.drop('survived', axis = 1)
y = df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25,
                                                    random_state = 123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  24%|████████████████████                                                               | 7/29 [00:00<00:01, 15.94it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [00:01<00:00, 18.36it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 15.37it/s]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RidgeClassifier                    1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# BernoulliNB                        1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# NuSVC                              0.99               0.99     0.99      0.99
# KNeighborsClassifier               0.99               0.99     0.99      0.99
# LabelSpreading                     0.98               0.98     0.98      0.98
# LabelPropagation                   0.98               0.98     0.98      0.98
# NearestCentroid                    0.92               0.91     0.91      0.92
# LinearDiscriminantAnalysis         0.84               0.82     0.82      0.84
# DummyClassifier                    0.55               0.52     0.52      0.55
# QuadraticDiscriminantAnalysis      0.62               0.50     0.50      0.48
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.06
# BaggingClassifier                    0.08
# XGBClassifier                        0.09
# SVC                                  0.04
# SGDClassifier                        0.03
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.04
# RandomForestClassifier               0.24
# Perceptron                           0.03
# PassiveAggressiveClassifier          0.03
# LogisticRegression                   0.05
# LinearSVC                            0.06
# GaussianNB                           0.04
# ExtraTreesClassifier                 0.20
# ExtraTreeClassifier                  0.05
# DecisionTreeClassifier               0.05
# CalibratedClassifierCV               0.17
# BernoulliNB                          0.04
# LGBMClassifier                       0.11
# NuSVC                                0.06
# KNeighborsClassifier                 0.05
# LabelSpreading                       0.07
# LabelPropagation                     0.06
# NearestCentroid                      0.04
# LinearDiscriminantAnalysis           0.05
# DummyClassifier                      0.04
# QuadraticDiscriminantAnalysis        0.03
